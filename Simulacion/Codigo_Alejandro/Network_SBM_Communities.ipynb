# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import networkx as nx
import numpy as np
##

# %%
def Two_Communities_random(n, p):
    sizes = [n, n]  # dos comunidades
    # Probabilidades de conexión
    p_in = 1-p        # intra-comunidad
    p_out = p     # inter-comunidad
    # Matriz de probabilidades
    probs = [[p_in, p_out],[p_out, p_in]]
    # Generar red SBM
    G = nx.stochastic_block_model(sizes, probs, seed=42) #Quitar seed si quieres redes aleatorias
    return G

# %%
G = Two_Communities_random(10, 0.1)

# %%
matA = 1.0*nx.adjacency_matrix(G).todense()
# Out:
# /tmp/ipykernel_27378/4292582531.py:1: FutureWarning: adjacency_matrix will return a scipy.sparse array instead of a matrix in Networkx 3.0.
#   matA = 1.0*nx.adjacency_matrix(G).todense()

# %%
plt.imshow(matA)
plt.show()
